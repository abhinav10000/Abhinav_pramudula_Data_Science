# %% [markdown]
#  # Going deeper with convolutions (Inception)

# %% [markdown]
# ## Abstract

# %% [markdown]
# ##### “Going deeper with convolutions” from which the hallmark idea of inception network came out.
#
# ##### Inception network was once considered a state-of-the-art deep learning architecture (or model) for solving image recognition and detection problems.
#
# It put forward a breakthrough performance on the ImageNet Visual Recognition Challenge (in 2014), which is a reputed platform for benchmarking image recognition and detection algorithms. Along with this, it set off a ton of research in the creation of new deep learning architectures with innovative and impactful ideas.

# %% [markdown]
# ## Prior related work:
#
# #### LeNet-5:
#
# convolutional neural networks (CNN) have typically had a standard structure – stacked convolutional layers are followed by one or more fully-connected (FC) layers
#
# This basic design are prevalent in the image classiﬁcation literature and have yielded the best results to-date on MNIST, CIFAR
#
# Despite concerns that max-pooling layers result in loss of accurate spatial information, the same convolutional network architecture as has also been successfully employed for localization object detection and human pose estimation
#
# Network-in-Network is an approach proposed by 'Lin et al' in order to increase the representational power ofneural networks
#
# When applied to convolutional layers,the method could be viewed as additional 1×1 convolutional layers followed typically by the rectiﬁed linear activation
#
# 1×1 convolutions have dual purpose: most critically, they are used mainly as dimension reduction modules to remove computational bottlenecks

# %% [markdown]
# ## What is an idea behind Inception Network and why inception?

# %% [markdown]
# There’s a simple but powerful way of creating better deep learning models.  You can just make a bigger model, either in terms of deepness, i.e., number of layers, or the number of neurons in each layer but it increases computations.
#
#
# Salient parts in the image can have extremely large variation in size.
#
# For instance, an image with a dog can be either of the following, as shown below
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Because of this huge variation in the location of the information, choosing the right kernel size for the convolution operation becomes tough.
# A larger kernel is preferred for information that is distributed more globally, and a smaller kernel is preferred for information that is distributed more locally.

# %% [markdown]
# Very deep networks are prone to overfitting. It also hard to pass gradient updates through the entire network.

# %% [markdown]
# #### Solution:
#
# Inception network says instead of choosing any one over the other let’s do them all.
#
# We concatenate all the layers together and let network learn whatever size it wants.
#
#
# But
#
#
#
# This increases the computational cost.
#
#
# Then....
#
# #### Bottleneck:
#
# To solve this we pass the data through 1*1 and then pass through bigger filters.
#
# Eg: 28 * 28 * 192 -> 1* 1 * 192 (16 channels) -> 5* 5 * 16 (32 channels)  = 28 * 28 * 32
#
# #### In bottleneck we shrink the representation before increase the size again
#
#
# #### Introduction of 1*1 layer reduces the cost of multiplication by more than 10
#
#
# i.e. paper suggests, to move on to sparsely connected network architectures which will replace fully connected network architectures, especially inside convolutional layers.
#
# #### Densely:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Sparsely:
# ![image.png](attachment:image.png)

# %% [markdown]
# ## ArchitecturalDetails

# %% [markdown]
# ##### The paper proposes a new type of architecture – GoogLeNet or Inception v1. It is basically a convolutional neural network (CNN) which is 27 layers deep

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# The inception layer is the core concept of a sparsely connected architecture.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Basic inception layer:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Hebbian principle:
#
# “neurons that fire together, wire together”
#
# It means, when creating a subsequent layer in a deep learning model, one should pay attention to the learnings of the previous layer.

# %% [markdown]
# ## Inception Version 1 - (GoogleNet)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Inception V2-

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Inception V3:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ##                                                            END
